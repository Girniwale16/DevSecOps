# %%
import pandas as pd

# %%
# Count the number of rows in the table
df = pd.read_csv("/Users/saurabh.aware/nexus-synth-studio/backend/data/exports/synthetic_577eb1bc-753b-4f5a-8973-a92bb16755c5.csv")
df.shape
# Out:
# (1000000, 5)

# %%
df.head()
# Out:
#          id           name                     email  age membership_status
# 0   5451002      Eve Davis  frankcharles@example.com   27              Gold
# 1   6046429   Frank Wilson        juan89@example.com   35            Silver
# 2  11509909  Charlie Brown       linda27@example.net   33            Silver
# 3   7602670   David Miller  deannabowman@example.net   34            Bronze
# 4   5066721   Grace Taylor     qgonzalez@example.com   27              Gold
